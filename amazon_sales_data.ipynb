# %% [markdown]
# <a href="https://colab.research.google.com/github/yash66gupta/Amazon-sales-data/blob/main/amazon_sales_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file = "/content/drive/MyDrive/Copy of Amazon Sales data.csv"

# %%
df = pd.read_csv(file)

# %%
df.head()
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# 0       Offline              H  5/28/2010  669165933  6/27/2010        9925
# 1        Online              C  8/22/2012  963881480  9/15/2012        2804
# 2       Offline              L   5/2/2014  341417157   5/8/2014        1779
# 3        Online              C  6/20/2014  514321792   7/5/2014        8102
# 4       Offline              L   2/1/2013  115456712   2/6/2013        5062
#
# ...

# %%
df.tail()
# Out:
#                 Region       Country      Item Type Sales Channel  \
# 95  Sub-Saharan Africa          Mali        Clothes        Online
# 96                Asia      Malaysia         Fruits       Offline
# 97  Sub-Saharan Africa  Sierra Leone     Vegetables       Offline
# 98       North America        Mexico  Personal Care       Offline
# 99  Sub-Saharan Africa    Mozambique      Household       Offline
#
#    Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 95              M   7/26/2011  512878119    9/3/2011         888      109.28
# 96              L  11/11/2011  810711038  12/28/2011        6267        9.33
# 97              C    6/1/2016  728815257   6/29/2016        1485      154.06
# 98              M   7/30/2015  559427106    8/8/2015        5767       81.73
# 99              L   2/10/2012  665095412   2/15/2012        5367      668.27
#
#     Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %%
df.shape
# Out:
# (100, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          100 non-null    object
#  1   Country         100 non-null    object
#  2   Item Type       100 non-null    object
#  3   Sales Channel   100 non-null    object
#  4   Order Priority  100 non-null    object
#  5   Order Date      100 non-null    object
#  6   Order ID        100 non-null    int64
#  7   Ship Date       100 non-null    object
#  8   Units Sold      100 non-null    int64
#  9   Unit Price      100 non-null    float64
#  10  Unit Cost       100 non-null    float64
#  11  Total Revenue   100 non-null    float64
#  12  Total Cost      100 non-null    float64
#  13  Total Profit    100 non-null    float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 11.1+ KB

# %% [markdown]
# **By using info we get to know, that the order date and shiping date are in the format of object. so, we"ll change the data type into datetime format.**

# %%
df['Ship Date']=pd.to_datetime(df['Ship Date'])
df['Order Date']=pd.to_datetime(df['Order Date'])

# %%
df.dtypes
# Out:
# Region                    object
# Country                   object
# Item Type                 object
# Sales Channel             object
# Order Priority            object
# Order Date        datetime64[ns]
# Order ID                   int64
# Ship Date         datetime64[ns]
# Units Sold                 int64
# Unit Price               float64
# Unit Cost                float64
# Total Revenue            float64
# Total Cost               float64
# Total Profit             float64
# dtype: object

# %%
len(df[df.duplicated()])
# Out:
# 0

# %%
df.duplicated().value_counts()
# Out:
# False    100
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
df.describe()
# Out:
#                 Order Date      Order ID            Ship Date   Units Sold  \
# count                  100  1.000000e+02                  100   100.000000
# mean   2013-09-16 14:09:36  5.550204e+08  2013-10-09 22:48:00  5128.710000
# min    2010-02-02 00:00:00  1.146066e+08  2010-02-25 00:00:00   124.000000
# 25%    2012-02-14 12:00:00  3.389225e+08  2012-02-24 18:00:00  2836.250000
# 50%    2013-07-12 12:00:00  5.577086e+08  2013-08-11 12:00:00  5382.500000
# 75%    2015-04-07 00:00:00  7.907551e+08  2015-04-28 00:00:00  7369.000000
# max    2017-05-22 00:00:00  9.940222e+08  2017-06-17 00:00:00  9925.000000
# std                    NaN  2.606153e+08                  NaN  2794.484562
#
#        Unit Price   Unit Cost  Total Revenue    Total Cost  Total Profit
# count  100.000000  100.000000   1.000000e+02  1.000000e+02  1.000000e+02
# mean   276.761300  191.048000   1.373488e+06  9.318057e+05  4.416820e+05
# min      9.330000    6.920000   4.870260e+03  3.612240e+03  1.258020e+03
# ...

# %%
df.nunique()
# Out:
# Region              7
# Country            76
# Item Type          12
# Sales Channel       2
# Order Priority      4
# Order Date        100
# Order ID          100
# Ship Date          99
# Units Sold         99
# Unit Price         12
# Unit Cost          12
# Total Revenue     100
# Total Cost        100
# Total Profit      100
# dtype: int64

# %% [markdown]
# **With the help of unique values. Now we know that there in our dataframe there are 7 region in which there are 76 countries are buying our product's.**

# %%
df.groupby('Sales Channel').count()['Item Type']
# Out:
# Sales Channel
# Offline    50
# Online     50
# Name: Item Type, dtype: int64

# %%
df.groupby('Region').count()['Country']
# Out:
# Region
# Asia                                 11
# Australia and Oceania                11
# Central America and the Caribbean     7
# Europe                               22
# Middle East and North Africa         10
# North America                         3
# Sub-Saharan Africa                   36
# Name: Country, dtype: int64

# %% [markdown]
# **With the help of groupby we get to know how many countries from which region are buying our product's. On the top Sub-Saharan Africa with 36 countries followed by Europe with 22 countries.**

# %%
df.groupby('Order Priority').count()['Item Type']
# Out:
# Order Priority
# C    22
# H    30
# L    27
# M    21
# Name: Item Type, dtype: int64

# %% [markdown]
# **There are four type of priorities available for order's**
#
# **critical, high, low, medium**

# %%
df[df['Order Priority']=="C"]['Item Type'].value_counts().plot(kind ='bar', title="Critical priority items")
# Out:
# <Axes: title={'center': 'Critical priority items'}, xlabel='Item Type'>

# %%
df[df['Order Priority']=="H"]['Item Type'].value_counts().plot(kind ='bar', title="High priority items")
# Out:
# <Axes: title={'center': 'High priority items'}, xlabel='Item Type'>

# %%
df[df['Order Priority']=="L"]['Item Type'].value_counts().plot(kind ='bar', title="Low priority items")
# Out:
# <Axes: title={'center': 'Low priority items'}, xlabel='Item Type'>

# %%
df[df['Order Priority']=="M"]['Item Type'].value_counts().plot(kind ='bar', title="Medium priority items")
# Out:
# <Axes: title={'center': 'Medium priority items'}, xlabel='Item Type'>

# %%
print(max(df['Order Date']))
print(min(df['Order Date']))
# Out:
# 2017-05-22 00:00:00
# 2010-02-02 00:00:00

# %% [markdown]
# **In that case now we know our time period of the data from which date to which date we need to analyze the sales.**

# %% [markdown]
# ### **From here we know our dataset completely what is available in this. so, now we"ll start analyzing our data.**
#
# **first of we will make a copy of this dataset so the changings will not affect the original dataset and then we will continue the operation's with the duplicate dataset.**

# %%
df1 = df.copy()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          100 non-null    object
#  1   Country         100 non-null    object
#  2   Item Type       100 non-null    object
#  3   Sales Channel   100 non-null    object
#  4   Order Priority  100 non-null    object
#  5   Order Date      100 non-null    datetime64[ns]
#  6   Order ID        100 non-null    int64
#  7   Ship Date       100 non-null    datetime64[ns]
#  8   Units Sold      100 non-null    int64
#  9   Unit Price      100 non-null    float64
#  10  Unit Cost       100 non-null    float64
#  11  Total Revenue   100 non-null    float64
#  12  Total Cost      100 non-null    float64
#  13  Total Profit    100 non-null    float64
# dtypes: datetime64[ns](2), float64(5), int64(2), object(5)
# memory usage: 11.1+ KB

# %%
df1.head(10)
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
# 5              Australia and Oceania        Solomon Islands        Baby Food
# 6                 Sub-Saharan Africa                 Angola        Household
# 7                 Sub-Saharan Africa           Burkina Faso       Vegetables
# 8                 Sub-Saharan Africa  Republic of the Congo    Personal Care
# 9                 Sub-Saharan Africa                Senegal           Cereal
#
#   Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# ...

# %% [markdown]
# **We wiil add some column's of profit per unit in this and month-year of order date**

# %%
df1['Month']=df1['Order Date'].dt.month
df1['Year']=df1['Order Date'].dt.year
df1['Unit Margine']=df1['Unit Price']-df1['Unit Cost']

# %%
df1
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %% [markdown]
# **Now it's time to find out. which type of item type has maximum and minimum margine**

# %%
# maximum unit margine
print(df1[df1['Unit Margine']==max(df1['Unit Margine'])]['Item Type'].unique())
# Out:
# ['Cosmetics']

# %%
#minimum unit margine
print(df1[df1['Unit Margine']==min(df1['Unit Margine'])]['Item Type'].unique())
# Out:
# ['Fruits']

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          100 non-null    object
#  1   Country         100 non-null    object
#  2   Item Type       100 non-null    object
#  3   Sales Channel   100 non-null    object
#  4   Order Priority  100 non-null    object
#  5   Order Date      100 non-null    datetime64[ns]
#  6   Order ID        100 non-null    int64
#  7   Ship Date       100 non-null    datetime64[ns]
#  8   Units Sold      100 non-null    int64
#  9   Unit Price      100 non-null    float64
#  10  Unit Cost       100 non-null    float64
#  11  Total Revenue   100 non-null    float64
#  12  Total Cost      100 non-null    float64
#  13  Total Profit    100 non-null    float64
#  14  Month           100 non-null    int32
#  15  Year            100 non-null    int32
#  16  Unit Margine    100 non-null    float64
# ...

# %%
df1.to_csv("Amazon_sales.csv")

# %%
df1
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
yearly_sales=df1.groupby('Year')["Total Revenue"].sum()

# %%
yearly_sales.name = "Yearly Sales"
yearly_sales.plot.pie(x='Total Revenue',autopct="%1.0f%%", subplots=True, fontsize=12, title='Yearly sales analysis', legend=False, figsize=(12,8))
# Out:
# array([<Axes: ylabel='Yearly Sales'>], dtype=object)

# %%
Region_sales=df1.groupby('Region')["Total Revenue"].sum()
Region_sales.name = "Sales by Region"
Region_sales.plot.pie(x='Total Reveneu',autopct="%1.0f%%", subplots=True, fontsize=12, title='Yearly sales analysis', legend=False, figsize=(12,6))
# Out:
# array([<Axes: ylabel='Sales by Region'>], dtype=object)

# %%
Yearly_profit=df1.groupby('Year')["Total Profit"].sum()
Yearly_profit.name = "Profit's per annum"
Yearly_profit.plot.bar(x='Total Profit',y= 'Year', subplots=True, fontsize=12, title='Yearly Profit analysis', legend=False, figsize=(12,8))
# Out:
# array([<Axes: title={'center': "Profit's per annum"}, xlabel='Year'>],
#       dtype=object)

# %%
Region_profit=df1.groupby('Region')["Total Profit"].sum()
Region_profit.name = "Profit's by Region"
Region_profit.plot.bar(x='Total Profit',y='Region',subplots= True, fontsize=10, title='Yearly Profit analysis', figsize=(10,5))
# Out:
# array([<Axes: title={'center': "Profit's by Region"}, xlabel='Region'>],
#       dtype=object)

# %%
Revenue_of_products=df1.groupby('Item Type')["Total Revenue"].sum()
Revenue_of_products.name = "Sum of revenue by product categories"
Revenue_of_products.plot.bar(x='Total Revenue',y= 'Item Type', subplots=True, fontsize=12, title='Sales by product categories', legend=False, figsize=(10,5))
# Out:
# array([<Axes: title={'center': 'Sum of revenue by product categories'}, xlabel='Item Type'>],
#       dtype=object)

# %%
Sales_by_channel=df1.groupby('Sales Channel')["Total Revenue"].sum()
Sales_by_channel.name = "Sales by Sales Channel"
Sales_by_channel.plot.pie(x='Sales Channel',autopct="%1.0f%%", subplots=True, fontsize=12, title='Yearly sales analysis', legend=False, figsize=(12,6))
# Out:
# array([<Axes: ylabel='Sales by Sales Channel'>], dtype=object)

# %%
Profit_by_channel=df1.groupby('Sales Channel')["Total Profit"].sum()
Profit_by_channel.name = "Profit by Sales Channel"
Profit_by_channel.plot.pie(x='Sales Channel',autopct="%1.0f%%", subplots=True, fontsize=12, title='Yearly profit analysis', legend=False, figsize=(12,6))
# Out:
# array([<Axes: ylabel='Profit by Sales Channel'>], dtype=object)

# %%
df1.dtypes
# Out:
# Region                    object
# Country                   object
# Item Type                 object
# Sales Channel             object
# Order Priority            object
# Order Date        datetime64[ns]
# Order ID                   int64
# Ship Date         datetime64[ns]
# Units Sold                 int64
# Unit Price               float64
# Unit Cost                float64
# Total Revenue            float64
# Total Cost               float64
# Total Profit             float64
# Month                      int32
# Year                       int32
# Unit Margine             float64
# dtype: object

# %%
df1['Year'] = df1['Year'].astype(int)

# %%
df1.dtypes
# Out:
# Region                    object
# Country                   object
# Item Type                 object
# Sales Channel             object
# Order Priority            object
# Order Date        datetime64[ns]
# Order ID                   int64
# Ship Date         datetime64[ns]
# Units Sold                 int64
# Unit Price               float64
# Unit Cost                float64
# Total Revenue            float64
# Total Cost               float64
# Total Profit             float64
# Month                      int32
# Year                       int64
# Unit Margine             float64
# dtype: object

# %%
yearly_sales = df1.groupby(["Year","Item Type"])["Total Revenue"].sum()

# %%
yearly_sales.plot.bar(x='Total Revenue', y=['Item Type', 'Year'], subplots=True, fontsize=12, title='Sales by product categories', legend=False, figsize=(18,6))
# Out:
# array([<Axes: title={'center': 'Total Revenue'}, xlabel='Year,Item Type'>],
#       dtype=object)

# %%
yearly_Profit = df1.groupby(["Year","Item Type"])["Total Profit"].sum()

# %%
#yearly_sales = yearly_sales.sort_values("Total Profit", ascending=False)

# %%
yearly_Profit.plot.bar(x='Total Profit', y=['Item Type', 'Year'], subplots=True, fontsize=12, title='Profit by product categories', legend=False, figsize=(20,6))
# Out:
# array([<Axes: title={'center': 'Total Profit'}, xlabel='Year,Item Type'>],
#       dtype=object)

# %%
Region_Sales = df1.groupby(["Region","Item Type"])["Total Revenue"].sum()

# %%
Region_Sales.plot.bar(x='Total Revenue', y=['Item Type', 'Region'], subplots=True, fontsize=12, title='Sales by product categories in Region', legend=False, figsize=(18,6))
# Out:
# array([<Axes: title={'center': 'Total Revenue'}, xlabel='Region,Item Type'>],
#       dtype=object)

# %%
Region_Profit = df1.groupby(["Region","Item Type"])["Total Profit"].sum()

# %%
Region_Profit.plot.bar(x='Total Profit', y=['Item Type', 'Region'], subplots=True, fontsize=12, title='Profit by product categories in Region', legend=False, figsize=(18,6))
# Out:
# array([<Axes: title={'center': 'Total Profit'}, xlabel='Region,Item Type'>],
#       dtype=object)
